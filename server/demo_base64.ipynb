# %%
import cv2
from matplotlib import pyplot as plt
import base64

# %%
img =cv2.imread("./test images/51f465e41dbadc549abdd64ba7ee166d.jpg")

# %%
plt.imshow(img)

# %%
encode = base64.b64encode(img)

# %%
#encode = encode.decode('utf-8')

# %%
import numpy as np
nparr = np.frombuffer(encode.decode('base64'), np.uint8)
img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In [53], line 2
#       1 import numpy as np
# ----> 2 nparr = np.frombuffer(encode.decode('base64'), np.uint8)
#       3 img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
#
# LookupError: 'base64' is not a text encoding; use codecs.decode() to handle arbitrary codecs

# %%
img = cv2.imread("J:\\Study Material\\Machine Learning Project\\Image Classifier ML-based\\server\\test images\\51f465e41dbadc549abdd64ba7ee166d.jpg")
plt.imshow(img)

# %%
face_classifier = cv2.CascadeClassifier("C:/Users/jonua/opencv-4.x/data/haarcascades/haarcascade_frontalface_default.xml")
eye_classifier = cv2.CascadeClassifier("C:/Users/jonua/opencv-4.x/data/haarcascades/haarcascade_eye.xml")

# %%
faces = face_classifier.detectMultiScale(img)

# %%
def crop_face(img_path="J:\Study Material\Machine Learning Project\Image Classifier ML-based\server\\test images\\643791-641790-roger-federer-aus-open-2018-afp.jpg"):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 4)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        plt.matshow(roi_color)
        eyes = eye_classifier.detectMultiScale(roi_gray)
        print(len(eyes))
        
faces = crop_face()
# Out:
# 2

# %%
faces
